# %%
library(data.table)

# %%
setwd("/data_alluser/CXY/keti/singlecell_eqtl/eqtl/result/COLOC/gwas_all")
rm(list=ls())

# %%
gwas_sort<-fread("/data_alluser/CXY/keti/singlecell_eqtl/eqtl/result/COLOC/coloc_gwas_pos_noNA_sort.txt")
dim(gwas_sort)
# Out:
# [1] 11555442        9

# %%
gwas_sort
# Out:
#          rsid         ALT REF      all_meta_AF all_inv_var_meta_beta
# 1        rs28888107   T   C        0.016700    -0.0422730
# 2        rs113106463  A   G        0.272100    -0.0437430
# 3        rs113656530  G   C        0.043300     0.0300230
# 4        rs111385029  G   A        0.028150     0.0261030
# 5        rs73138514   G   A        0.034250     0.0247530
# 6        rs114792740  T   G        0.008865     0.0666510
# 7        rs73138516   C   T        0.034540     0.0279370
# 8        rs73910134   G   A        0.034160     0.0333050
# 9        rs13390778   G   C        0.049560     0.0182250
# 10       rs1382816570 G   C        0.185900     0.0668710
# 11       rs1407981181 A   C        0.814900     0.0295650
# 12       rs1238540810 C   A        0.814800     0.0300890
# 13       rs10172629   T   C        0.014000     0.0224530
# 14       rs1271483947 C   T        0.821700     0.0349460
# 15       rs10172644   G   C        0.073550     0.0319700
# ...

# %%
#gwas_sort<-fread("/data_alluser/CXY/keti/singlecell_eqtl/eqtl/result/COLOC/GWAS_5E-8.txt")

# %%
gwas<-na.omit(gwas_sort)
gwas1<-gwas
dim(gwas1)
# Out:
# [1] 11555442        9

# %%
#gwas1<-gwas[which((gwas$all_inv_var_meta_p<0.00005)==TRUE),]
#dim(gwas1)
# Out:
# [1] 10602     9

# %%
j=1
aaa<-gwas1$POS[1]+1000000
for(i in 1:nrow(gwas1)){
  if(j<=nrow(gwas1)){
    while(j<=nrow(gwas1)){
    if(gwas1$POS[j]<=aaa){
      gwas1$group[j]<-i
      j=j+1
    } else {
      gwas1$group[j]<-i+1
      aaa<-gwas1$POS[j]+1000000
      j=j+1
      break
    }
   print(j) 

  }
  }else{
    break
  }
}

# %%
#write.table (gwas1,"/data_alluser/CXY/keti/singlecell_eqtl/eqtl/result/COLOC/GWAS_5E-8.txt",sep="\t",quote=F,row.names=F)

# %%
write.table (gwas1,"/data_alluser/CXY/keti/singlecell_eqtl/eqtl/result/COLOC/GWAS_all.txt",sep="\t",quote=F,row.names=F)

# %%
gwas111<-fread("/data_alluser/CXY/keti/singlecell_eqtl/eqtl/result/COLOC/GWAS_all.txt")

# %%
b2<-list()
c1<-list()
for( j in 1:138)
{
   
   for( i in 1:nrow(gwas111))
      {      
          if(gwas111[i,10]==j)
           {          
           a<-gwas111[i,]
           a1<-a[,-c(9,10)]        
           c<-rbind(b2,a1) 
           c1<-rbind(c1,c) 
           print(c(i,j))
           #print(paste0(i,sep=",",j)) 
            }
           
       }
        
 write.table(c1,paste0("/data_alluser/CXY/keti/singlecell_eqtl/eqtl/result/COLOC/222/" ,a[1,10],".csv"),sep=",",quote=F,row.names=F)
        c1<-list()
         
}
# Out:
# [1] 1 1
# [1] 2 1
# [1] 3 1
# [1] 4 2
# [1] 5 2
# [1] 6 2
# [1] 7 2
# [1] 8 2
# [1] 9 2
# [1] 10  2
# [1] 11  2
# [1] 12  2
# [1] 13  2
# [1] 14  2
# [1] 15  2
# [1] 16  2
# [1] 17  2
# [1] 18  2
# [1] 19  2
# [1] 20  2
# [1] 21  2
# [1] 22  2
# [1] 23  2
# [1] 24  2
# [1] 25  2
# [1] 26  2
# [1] 27  2
# [1] 28  2
# [1] 29  2
# [1] 30  2
# [1] 31  2
# [1] 32  2
# [1] 33  2
# [1] 34  2
# [1] 35  2
# [1] 36  2
# [1] 37  2
# [1] 38  2
# [1] 39  2
# [1] 40  2
# [1] 41  2
# [1] 42  2
# [1] 43  2
# [1] 44  2
# [1] 45  3
# [1] 46  3
# [1] 47  3
# [1] 48  3
# [1] 49  3
# [1] 50  3
# [1] 51  3
# [1] 52  3
# [1] 53  3
# [1] 54  3
# [1] 55  3
# [1] 56  3
# [1] 57  3
# [1] 58  3
# [1] 59  3
# [1] 60  3
# [1] 61  3
# [1] 62  3
# [1] 63  3
# [1] 64  3
# [1] 65  3
# [1] 66  3
# [1] 67  3
# [1] 68  3
# [1] 69  3
# [1] 70  3
# [1] 71  3
# [1] 72  3
# [1] 73  3
# [1] 74  3
# [1] 75  3
# [1] 76  3
# [1] 77  3
# [1] 78  3
# [1] 79  3
# [1] 80  3
# [1] 81  3
# [1] 82  3
# [1] 83  3
# [1] 84  3
# ...
